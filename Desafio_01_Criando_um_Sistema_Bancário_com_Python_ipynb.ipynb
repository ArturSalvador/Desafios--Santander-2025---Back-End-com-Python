# %%
menu = """

[d] Depositar
[s] Sacar
[e] Extrato
[q] Sair

=> """

saldo = 0
limite = 500
extrato = ""
numero_saques = 0
LIMITE_SAQUES = 3

while True:
  opcao = input(menu)
  if opcao == "d":
      print("Deposito")
      dep = float(input("Qual é o valor que você deseja depositar??  "))
      if dep > 0:
        saldo += dep
        extrato += f"Depósito: R${dep:.2f}\n"
        print(f" Foram depoisitado R${dep:.2f} e o eu saldo é de R${saldo:.2f}")
      else:
        print("Valor inválido")
  elif opcao == "s":
      print("Saque")
      if numero_saques >= 3:
        print("Limite de saques atingido")
      else:
        saq = float(input("Qual é o valor que você deseja sacar??  "))
        if saq <= saldo:
          saldo -= saq
          numero_saques += 1
          extrato += f"Saque: R${saq:.2f}\n"
          print(f"Foram sacadas R${saq:.2f} e o saldo é de R${saldo:.2f}")
        elif saq > limite:
          print("Limite de saque excedido")
        elif saq > saldo:
          print("Saldo insuficiente")
        else:
          print("Operação falhou! O valor informado é inválido")
  elif opcao == "e":
      print("\n================================= EXTRATO =================================")
      print("Não foram realizadas movimentações." if not extrato else extrato)
      print(f"\n Saldo: R${saldo:.2f}")
      print("============================================================================")
  elif opcao == "q":
      print("Saindo...")
      break
  else:
      print("Operação inválida, por favor selecione novamente a operação desejada.")
# Out:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [q] Sair
#
# => d
# Deposito
# Qual é o valor que você deseja depositar??  3000
#  Foram depoisitado R$3000.00 e o eu saldo é de R$3000.00
#
#
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [q] Sair
#
# => e
#
# ================================= EXTRATO =================================
# Depósito: R$3000.00
#
#
#  Saldo: R$3000.00
# ============================================================================
#
#
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [q] Sair
#
# => s
# Saque
# Qual é o valor que você deseja sacar??  10
# Foram sacadas R$10.00 e o saldo é de R$2990.00
#
#
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [q] Sair
#
# => s
# Saque
# Qual é o valor que você deseja sacar??  10
# Foram sacadas R$10.00 e o saldo é de R$2980.00
#
#
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [q] Sair
#
# => s
# Saque
# Qual é o valor que você deseja sacar??  10
# Foram sacadas R$10.00 e o saldo é de R$2970.00
#
#
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [q] Sair
#
# => e
#
# ================================= EXTRATO =================================
# Depósito: R$3000.00
# Saque: R$10.00
# Saque: R$10.00
# Saque: R$10.00
#
#
#  Saldo: R$2970.00
# ============================================================================
#
#
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [q] Sair
#
# => s
# Saque
# Limite de saques atingido
#
#
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [q] Sair
#
# => e
#
# ================================= EXTRATO =================================
# Depósito: R$3000.00
# Saque: R$10.00
# Saque: R$10.00
# Saque: R$10.00
#
#
#  Saldo: R$2970.00
# ============================================================================
#
#
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [q] Sair
#
# => s
# Saque
# Limite de saques atingido
#
#
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [q] Sair
#
# => q
# Saindo...
